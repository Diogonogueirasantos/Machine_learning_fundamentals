# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('titanic.csv')

# %%
profile = ProfileReport(df, 'Resumo')
# Out:
# ---------------------------------------------------------------------------
# TypeCheckError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 profile = ProfileReport(df, 'Resumo')
#
# File ~/anaconda3/envs/Machine_learning/lib/python3.13/site-packages/ydata_profiling/profile_report.py:68, in ProfileReport.__init__(self, df, minimal, tsmode, sortby, sensitive, explorative, sample, config_file, lazy, typeset, summarizer, config, type_schema, **kwargs)
#      65 _json = None
#      66 config: Settings
# ---> 68 def __init__(
#      69     self,
#      70     df: Optional[Union[pd.DataFrame, sDataFrame]] = None,
#      71     minimal: bool = False,
#      72     tsmode: bool = False,
#      73     sortby: Optional[str] = None,
#      74     sensitive: bool = False,
#      75     explorative: bool = False,
#      76     sample: Optional[dict] = None,
#      77     config_file: Optional[Union[Path, str]] = None,
#      78     lazy: bool = True,
# ...
